# %% [markdown]
# 均线

# %%
import pandas as pd
import matplotlib
from matplotlib import font_manager
import matplotlib.pyplot as plt
from datetime import datetime
import json
import numpy as np
import cnfundutils
import libtrdb2
import trading2_pb2
import tradingdb2_pb2
import tradingdb2_pb2_grpc

import plotly.express as px

isStaticImg = True

cnfundutils.init2()

trdb2cfg = libtrdb2.loadConfig('./trdb2.yaml')

FUNDRESULTS_PATH = './calcfundfull.csv'
dfFundResults = cnfundutils.loadFundResult(FUNDRESULTS_PATH)

FUNDS_PATH = './funds.xlsx'
dfFunds = cnfundutils.loadFundBasicInfo(FUNDS_PATH)

# %%
lststart = [1, 2, 3, 4, 5]
lstend = [2, 3, 4, 5, 1]
lsttitle = ['周一', '周二', '周三', '周四', '周五']
lstdf = []
assets = ['cnfunds.510310']

buy0 = trading2_pb2.CtrlCondition(
    name='indicatorsp',
    operators=['upcross'],
    strVals=['ema.20'],
)

sell0 = trading2_pb2.CtrlCondition(
    name='indicatorsp',
    operators=['downcross'],
    strVals=['ema.20'],
)

paramsbuy = trading2_pb2.BuyParams(
    perHandMoney=1,
)

paramssell = trading2_pb2.SellParams(
    perVolume=1,
)

paramsinit = trading2_pb2.InitParams(
    money=10000,
)

df0 = libtrdb2.simTradingEx(trdb2cfg, assets, 0, -1, buy0, sell0, paramsbuy, paramssell, paramsinit, None)
lstdf.append({'title': 'ema20', 'df': df0})

# baseline    
buy0 = trading2_pb2.CtrlCondition(
    indicator='buyandhold',
)

paramsbuy = trading2_pb2.BuyParams(
    perHandMoney=1,
)

paramsinit = trading2_pb2.InitParams(
    money=10000,
)

df0 = libtrdb2.simTradingEx(trdb2cfg, assets, 0, -1, buy0, None, paramsbuy, None, paramsinit, None)
lstdf.append({'title': 'baseline', 'df': df0})    

libtrdb2.showSimTradingEx('ema20交叉买卖', lstdf, False)
# Out:
# <div>                            <div id="bdb03e5b-6cd6-4c88-a314-96d3c3b8a07a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bdb03e5b-6cd6-4c88-a314-96d3c3b8a07a")) {                    Plotly.newPlot(                        "bdb03e5b-6cd6-4c88-a314-96d3c3b8a07a",                        [{"mode": "lines", "name": "ema20", "type": "scatter", "x": ["2013-03-08", "2013-03-15", "2013-03-18", "2013-03-19", "2013-03-20", "2013-03-21", "2013-03-22", "2013-03-25", "2013-03-26", "2013-03-27", "2013-03-28", "2013-03-29", "2013-04-01", "2013-04-02", "2013-04-03", "2013-04-08", "2013-04-09", "2013-04-10", "2013-04-11", "2013-04-12", "2013-04-15", "2013-04-16", "2013-04-17", "2013-04-18", "2013-04-19", "2013-04-22", "2013-04-23", "2013-04-24", "2013-04-25", "
# ...
