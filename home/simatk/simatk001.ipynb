# %%
import json
from datetime import datetime
import pandas as pd
import plotly.graph_objects as go

# %%
def loadjson(fn):
    f = open(fn)
    buf = f.read()
    f.close()
    
    obj = json.loads(buf)
    return obj

# %%
obj = loadjson('./simatk001.json')

# %%
obj
# Out:
# {'title': '基础战斗模拟',
#  'results': [{'Units': [{'Props': {'1': 10, '100': 0, '101': 190, '2': 190},
#      'UnitType': 2},
#     {'Props': {'1': 11, '100': -9, '101': 189, '2': 189}, 'UnitType': 2}],
#    'WinIndex': 0,
#    'FirstIndex': 0},
#   {'Units': [{'Props': {'1': 10, '100': 0, '101': 190, '2': 190},
#      'UnitType': 2},
#     {'Props': {'1': 11, '100': -9, '101': 189, '2': 189}, 'UnitType': 2}],
#    'WinIndex': 1,
#    'FirstIndex': 1},
#   {'Units': [{'Props': {'1': 10, '100': 0, '101': 190, '2': 190},
#      'UnitType': 2},
#     {'Props': {'1': 12, '100': -8, '101': 188, '2': 188}, 'UnitType': 2}],
#    'WinIndex': 0,
#    'FirstIndex': 0},
#   {'Units': [{'Props': {'1': 10, '100': 0, '101': 190, '2': 190},
#      'UnitType': 2},
#     {'Props': {'1': 12, '100': -8, '101': 188, '2': 188}, 'UnitType': 2}],
#    'WinIndex': 1,
#    'FirstIndex': 1},
#   {'Units': [{'Props': {'1': 10, '100': 0, '101': 190, '2': 190},
#      'UnitType': 2},
# ...
